# %%
import math

peso = 65
altura = 1.75

IMC = peso / (altura**2)

print(f"IMC = {IMC}")

if IMC < 18.5:
    print("Abaixo do peso")
elif IMC >= 18.5 and IMC <= 24.9:
    print("Peso normal")
elif IMC >= 25 and IMC <= 29.9:
    print("Sobrepeso")
# Out:
# IMC = 21.224489795918366
# Peso normal
